# %%
conda create --name textmining python 3.8
# Out:
# Channels:
#  - defaults
# Platform: osx-arm64
# ...
# Solving environment: failed
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - 3.8
#
# Current channels:
#
#   - defaults
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
python version
# Out:
#   Cell In[5], line 1
#     python version
#            ^
# SyntaxError: invalid syntax

# %%
python --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 python --version
#
# NameError: name 'python' is not defined

# %%
import pandas as pd

# %%
import pandas as pd

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv('data/song_lyrics_en.csv')

df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/q9/9k2w8bsd34qgsvh9fhyvsdch0000gn/T/ipykernel_1762/1318355638.py in <cell line: 4>()
#       2
#       3 # Load your dataset
# ----> 4 df = pd.read_csv('data/song_lyrics_en.csv')
#       5
#       6 df.head()
#
# ...
